# %%
# =========================================================
# GRU MULTICLASS IDS – FINAL (BiGRU + CONFUSION MATRIX)
# =========================================================

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import pandas as pd
import numpy as np
import tensorflow as tf
import random
import time
import seaborn as sns
import matplotlib.pyplot as plt
import shap

from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score
from xgboost import XGBClassifier

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, GRU, Dense, Dropout, BatchNormalization, Bidirectional
from tensorflow.keras.utils import to_categorical
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Layer

# =========================================================
# SEED
# =========================================================
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)

# =========================================================
# LOAD DATASET
# =========================================================
base_path = "/content/drive/MyDrive/UNSW-NB15/"

train_df = pd.read_csv(base_path + "UNSW_NB15_training-set.csv")
test_df  = pd.read_csv(base_path + "UNSW_NB15_testing-set.csv")

train_df.drop(columns=["id"], inplace=True)
test_df.drop(columns=["id"], inplace=True)

train_df["label"] = train_df["attack_cat"]
test_df["label"]  = test_df["attack_cat"]

train_df.drop(columns=["attack_cat"], inplace=True)
test_df.drop(columns=["attack_cat"], inplace=True)

train_df = train_df.dropna(subset=["label"])
test_df  = test_df.dropna(subset=["label"])

# =========================================================
# LABEL ENCODE CATEGORICAL
# =========================================================
cat_cols = ["proto","service","state"]

for col in cat_cols:
    le_temp = LabelEncoder()
    le_temp.fit(pd.concat([train_df[col], test_df[col]]))
    train_df[col] = le_temp.transform(train_df[col])
    test_df[col]  = le_temp.transform(test_df[col])

# =========================================================
# SPLIT
# =========================================================
train_df, val_df = train_test_split(
    train_df,
    test_size=0.25,
    stratify=train_df["label"],
    random_state=42
)

# =========================================================
# XGBOOST FEATURE SELECTION
# =========================================================
X_fs = train_df.drop("label", axis=1)
y_fs = train_df["label"].values

le_fs = LabelEncoder()
y_fs_enc = le_fs.fit_transform(y_fs)

xgb = XGBClassifier(n_estimators=150, max_depth=6, learning_rate=0.1,
                    random_state=42, eval_metric="mlogloss")

xgb.fit(X_fs, y_fs_enc)

importance = xgb.feature_importances_
features = X_fs.columns

feat_df = pd.DataFrame({"Feature":features,"FI":importance})
feat_df = feat_df.sort_values("FI",ascending=False)

top_features = list(feat_df.head(17)["Feature"])
print("Top Features:", top_features)

# =========================================================
# DATA PREP
# =========================================================
X_train = train_df[top_features]
X_val   = val_df[top_features]
X_test  = test_df[top_features]

y_train = train_df["label"]
y_val   = val_df["label"]
y_test  = test_df["label"]

le = LabelEncoder()
y_train_enc = le.fit_transform(y_train)
y_val_enc   = le.transform(y_val)
y_test_enc  = le.transform(y_test)

num_classes = len(le.classes_)

y_train = to_categorical(y_train_enc, num_classes)
y_val   = to_categorical(y_val_enc, num_classes)
y_test  = to_categorical(y_test_enc, num_classes)

scaler = MinMaxScaler()

X_train = scaler.fit_transform(X_train)
X_val   = scaler.transform(X_val)
X_test  = scaler.transform(X_test)

X_train = X_train.reshape(-1, 1, len(top_features))
X_val   = X_val.reshape(-1, 1, len(top_features))
X_test  = X_test.reshape(-1, 1, len(top_features))

# =========================================================
# ATTENTION
# =========================================================
class AttentionLayer(Layer):
    def build(self,input_shape):
        self.W=self.add_weight(shape=(input_shape[-1],1),initializer="normal")
        self.b=self.add_weight(shape=(input_shape[1],1),initializer="zeros")
        super().build(input_shape)

    def call(self,x):
        e=K.tanh(K.dot(x,self.W)+self.b)
        a=K.softmax(e,axis=1)
        output=x*a
        return K.sum(output,axis=1)

# =========================================================
# BiGRU MODEL
# =========================================================
def build_bigru(nu):

    inputs = Input(shape=(1,len(top_features)))

    x = Bidirectional(GRU(nu, return_sequences=True))(inputs)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)

    x = Bidirectional(GRU(nu, return_sequences=True))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)

    x = Bidirectional(GRU(nu, return_sequences=True))(x)

    x = AttentionLayer()(x)

    x = Dense(nu//2, activation="relu")(x)
    outputs = Dense(num_classes, activation="softmax")(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(0.001),
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

# =========================================================
# TRAIN LOOP
# =========================================================
NU_list = [32, 64, 128]
results = []
best_TAC = 0

for nu in NU_list:

    print("\nTraining BiGRU NU =", nu)

    start = time.time()

    model = build_bigru(nu)

    history = model.fit(
        X_train, y_train,
        epochs=25,
        batch_size=256,
        validation_data=(X_val, y_val),
        verbose=1
    )

    training_time = time.time() - start

    probs = model.predict(X_test)
    preds = np.argmax(probs, axis=1)

    TAC = accuracy_score(y_test_enc, preds)
    F1  = f1_score(y_test_enc, preds, average="weighted")
    VAC = max(history.history["val_accuracy"])

    results.append([nu, VAC, TAC, F1, training_time])

    # Save best model
    if TAC > best_TAC:
        best_TAC = TAC
        best_model = model

# =========================================================
# RESULTS TABLE
# =========================================================
results_df = pd.DataFrame(
    results,
    columns=["NU","VAC","TAC","F1","Training Time"]
)

print(results_df)

# =========================================================
# CONFUSION MATRIX (ADDED)
# =========================================================
print("\nConfusion Matrix (Multiclass UNSW-NB15)")

probs = best_model.predict(X_test)
preds = np.argmax(probs, axis=1)

cm = confusion_matrix(y_test_enc, preds)

plt.figure(figsize=(8,6))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=le.classes_,
    yticklabels=le.classes_
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Multiclass Confusion Matrix - UNSW-NB15")
plt.show()

# =========================================================
# SHAP
# =========================================================
X_train_flat = X_train.reshape(X_train.shape[0], X_train.shape[2])
X_test_flat  = X_test.reshape(X_test.shape[0], X_test.shape[2])

def predict_flat(x):
    x = x.reshape(x.shape[0], 1, x.shape[1])
    return best_model.predict(x)

explainer = shap.KernelExplainer(predict_flat, X_train_flat[:100])
shap_values = explainer.shap_values(X_test_flat[:50])

shap.summary_plot(
    shap_values,
    X_test_flat[:50],
    feature_names=top_features
)
# Out:
# Mounted at /content/drive
# Top Features: ['dttl', 'sttl', 'sbytes', 'service', 'ct_srv_dst', 'swin', 'ct_dst_src_ltm', 'ct_dst_sport_ltm', 'tcprtt', 'dmean', 'dbytes', 'proto', 'smean', 'synack', 'ct_src_dport_ltm', 'ct_state_ttl', 'ct_srv_src']
#
# Training BiGRU NU = 32
# Epoch 1/25
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 16s 25ms/step - accuracy: 0.6943 - loss: 0.9352 - val_accuracy: 0.5343 - val_loss: 1.6507
# Epoch 2/25
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0
25
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.8508 - loss: 0.3879 - val_accuracy: 0.8459 - val_loss: 0.4093
# Epoch 12/25
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8525 - loss: 0.3842 - val_accuracy: 0.8521 - val_loss: 0.3944
# Epoch 13/25
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.8528 - loss: 0.3811 - val_accuracy: 0.8534 - val_loss: 0.3843
# Epoch 14/25
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.8536 - loss: 0.3783 - val_accuracy: 0.8529 - val_loss: 0.3858
# Epoch 15/25
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.8558 - loss: 0.3734 - val_accuracy: 0.8512 - val_loss: 0.3941
# Epoch 16/25
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.8570 - loss: 0.3698 - val_accuracy: 0.8463 - val_loss: 0.4050
# Epoch 17/25
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.8570 - loss: 0.3696 - val_accuracy: 0.8549 - val_loss: 0.3825
# Epoch 18/25
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.8563 - loss: 0.3674 - val_accuracy: 0.8475 - val_loss: 0.3943
# Epoch 19/25
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8576 - loss: 0.3650 - val_accuracy: 0.8514 - val_loss: 0.3889
# Epoch 20/25
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.8579 - loss: 0.3637 - val_accuracy: 0.8558 - val_loss: 0.3797
# Epoch 21/25
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.8594 - loss: 0.3604 - val_accuracy: 0.8494 - val_loss: 0.3979
# Epoch 22/25
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8598 - loss: 0.3584 - val_accuracy: 0.8578 - val_loss: 0.3720
# Epoch 23/25
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.8597 - loss: 0.3572 - val_accuracy: 0.8520 - val_loss: 0.3856
# Epoch 24/25
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.8601 - loss: 0.3559 - val_accuracy: 0.8549 - val_loss: 0.3753
# Epoch 25/25
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.8597 - loss: 0.3550 - val_accuracy: 0.8473 - val_loss: 0.4037
# 5480/5480 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step
#     NU       VAC       TAC        F1  Training Time
# 0   32  0.851674  0.736998  0.693124     129.235634
# 1   64  0.856532  0.750287  0.704195     137.238819
# 2  128  0.857844  0.746865  0.706912     148.221854
#
# Confusion Matrix (Multiclass UNSW-NB15)
# 5480/5480 ━━━━━━━━━━━━━━━━━━━━ 22s 4ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#   0%|          | 0/50 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 6507/6507 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step
# /tmp/ipykernel_1799/2970211827.py:263: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(
# /usr/local/lib/python3.12/dist-packages/shap/plots/_beeswarm.py:723: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   summary_legacy(
# /usr/local/lib/python3.12/dist-packages/shap/plots/_beeswarm.py:743: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   summary_legacy(
# /usr/local/lib/python3.12/dist-packages/shap/plots/_beeswarm.py:743: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   summary_legacy(
# /usr/local/lib/python3.12/dist-packages/shap/plots/_beeswarm.py:743: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   summary_legacy(
# /usr/local/lib/python3.12/dist-packages/shap/plots/_beeswarm.py:743: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   summary_legacy(
# /usr/local/lib/python3.12/dist-packages/shap/plots/_beeswarm.py:743: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   summary_legacy(
# /usr/local/lib/python3.12/dist-packages/shap/plots/_beeswarm.py:743: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   summary_legacy(
